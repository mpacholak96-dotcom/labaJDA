# %% [markdown]
# # Zajęcia 22: Wprowadzenie do Pandas
#
# ## Instalacja i importowanie Pandas

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Series - podstawowy typ danych w Pandas
# Series to jednowymiarowa struktura danych, przypominająca listę lub słownik.

# %%
# Tworzenie Series z domyślnym indeksem
data = [10, 20, 30, 40]
series = pd.Series(data)
print(series)

# Tworzenie Series z własnym indeksem
index_nasz = ['a', 'b', 'c', 'd']
series_custom = pd.Series(data, index=index_nasz)

print(series_custom)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# ### Ćwiczenie:
# Stwórz własny obiekt Series z pięcioma wartościami (możesz użyć `range`) i niestandardowym indeksem.

# %%
nasz_series = pd.Series(range(0, 5), index = range(1,6))
nasz_series
# Out:
# 1    0
# 2    1
# 3    2
# 4    3
# 5    4
# dtype: int64

# %% [markdown]
# ## DataFrame - dwuwymiarowa tabela podobna do Excela

# %%
data = {
    'Imię': ['Jan', 'Anna', 'Tomasz'],
    'Wiek': [25, 30, 35],
    'Miasto': ['Warszawa', 'Kraków', 'Gdańsk']
}

df = pd.DataFrame(data) # Łatwo tworzone ze słowników

# Różnica między print a display
print(df)
display(df)

# Wywoływanie indeksów i kolumn
print(df.columns)
print(df.index)
# Out:
#      Imię  Wiek    Miasto
# 0     Jan    25  Warszawa
# 1    Anna    30    Kraków
# 2  Tomasz    35    Gdańsk
#      Imię  Wiek    Miasto
# 0     Jan    25  Warszawa
# 1    Anna    30    Kraków
# 2  Tomasz    35    Gdańsk
# Index(['Imię', 'Wiek', 'Miasto'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)

# %%
data_bez_imie = {
    'Wiek': [25, 30, 35],
    'Miasto': ['Warszawa', 'Kraków', 'Gdańsk']
}

imiona = ['Jan', 'Anna', 'Tomasz']
# Używanie indeksu innego niż domyślny
df = pd.DataFrame(data_bez_imie, index = imiona)
display(df)
print(df.index)

# UWAGA NA RESET_INDEX!
display(df.reset_index())
# Out:
#         Wiek    Miasto
# Jan       25  Warszawa
# Anna      30    Kraków
# Tomasz    35    Gdańsk
# Index(['Jan', 'Anna', 'Tomasz'], dtype='object')
#     index  Wiek    Miasto
# 0     Jan    25  Warszawa
# 1    Anna    30    Kraków
# 2  Tomasz    35    Gdańsk

# %%
# Alternatywne ustawienie indeksu innego niż domyślny
df = pd.DataFrame(data)
df = df.set_index('Imię')
display(df)
print(df.index)

# Powrót indeksu do kolumny
df = df.reset_index(drop = False)
display(df)
# Out:
#         Wiek    Miasto
# Imię
# Jan       25  Warszawa
# Anna      30    Kraków
# Tomasz    35    Gdańsk
# Index(['Jan', 'Anna', 'Tomasz'], dtype='object', name='Imię')
#      Imię  Wiek    Miasto
# 0     Jan    25  Warszawa
# 1    Anna    30    Kraków
# 2  Tomasz    35    Gdańsk

# %% [markdown]
# ## Importowanie danych

# %%
# Importowanie danych z pliku CSV
train_path = "D:/python/labaJDA/input/titanic/train.csv"

# Jeżeli nie działa, podaj swoją lokalizację pliku
# sep - znak oddzielający komurki, decimal - znak między jednościami a częścią dziesiętną
df_titanic = pd.read_csv('../input/titanic/train.csv', sep = ',', decimal = '.') 
#df_titanic2 = pd.read_csv(train_path)
df_titanic.info()
#
display(df_titanic.describe()) # dla kolumn liczbowych
#
## Alternatywne wyjścia dla ustawienia indeksu
df_titanic = df_titanic.set_index('PassengerId')
df_titanic = pd.read_csv('../input/titanic/train.csv', index_col= "PassengerId") 

#
display(df_titanic.head())  # Podgląd pierwszych 5 wierszy
display(df_titanic.tail(10))  # Podgląd ostatnich 10 wierszy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#              Survived  Pclass                                      Name  \
# PassengerId
# 882                 0       3                        Markun, Mr. Johann
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 884                 0       2             Banfield, Mr. Frederick James
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 882            male  33.0      0      0            349257   7.8958   NaN
# 883          female  22.0      0      0              7552  10.5167   NaN
# 884            male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN
# 885            male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN
# 886          female  39.0      0      5            382652  29.1250   NaN
# 887            male  27.0      0      0            211536  13.0000   NaN
# 888          female  19.0      0      0            112053  30.0000   B42
# 889          female   NaN      1      2        W./C. 6607  23.4500   NaN
# 890            male  26.0      0      0            111369  30.0000  C148
# 891            male  32.0      0      0            370376   7.7500   NaN
#
#             Embarked
# PassengerId
# 882                S
# 883                S
# 884                S
# 885                S
# 886                Q
# 887                S
# 888                S
# 889                S
# 890                C
# 891                Q

# %%
# Importowanie danych z pliku Excel
df_tdf = pd.read_excel('../input/tour_de_france/tour_de_france.xlsx', sheet_name='Stats', index_col='Year')
display(df_tdf.head())
# Out:
#       Winner's avg speed  Total distance (km)  Number of stages  Finishers  \
# Year
# 1903               25.68               2428.0                 6         21
# 1904               25.27               2420.0                 6         27
# 1905               27.11               2994.0                11         24
# 1906               24.46               4545.0                13         14
# 1907               28.47               4488.0                14         33
#
#       Entrants               Winner Winner's Nationality   Winner's Team  \
# Year
# 1903        60        Maurice Garin               France    La Française
# 1904        88         Henri Cornet               France       Cycles JC
# 1905        60    Louis Trousselier               France  Cycles Peugeot
# 1906        82         René Pottier               France  Cycles Peugeot
# 1907        93  Lucien Petit-Breton               France  Cycles Peugeot
#
#      Start Date   End Date Starting city  Starting city Latitude  \
# Year
# 1903 1903-07-01 1903-07-21         Paris                 48.8566
# 1904 1904-07-02 1904-07-24         Paris                 48.8566
# 1905 1905-07-09 1905-07-30         Paris                 48.8566
# 1906 1906-07-04 1906-07-29         Paris                 48.8566
# 1907 1907-07-08 1907-08-04         Paris                 48.8566
#
#       Starting city Longitude Starting country Finishing city  \
# Year
# 1903                   2.3522           France          Paris
# 1904                   2.3522           France          Paris
# 1905                   2.3522           France          Paris
# 1906                   2.3522           France          Paris
# 1907                   2.3522           France          Paris
#
#       Finishing city Latitude  Finishing city Longitude
# Year
# 1903                  48.8566                    2.3522
# 1904                  48.8566                    2.3522
# 1905                  48.8566                    2.3522
# 1906                  48.8566                    2.3522
# 1907                  48.8566                    2.3522

# %% [markdown]
# ### Ćwiczenie:
# 1. Zaczytaj plik z lokacji `../input/titanic/test.csv`
# 2. ustaw index `PassengerId`
# 3. Wyświetl pierwszych 10 wierszy

# %%
test_location = '../input/titanic/test.csv'
df_test = pd.read_csv(test_location, index_col = 'PassengerId')

display(df_test.head(10))
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 897               3                    Svensson, Mr. Johan Cervin    male
# 898               3                          Connolly, Miss. Kate  female
# 899               2                  Caldwell, Mr. Albert Francis    male
# 900               3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 901               3                       Davies, Mr. John Samuel    male
#
#               Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0     330911   7.8292   NaN        Q
# 893          47.0      1      0     363272   7.0000   NaN        S
# 894          62.0      0      0     240276   9.6875   NaN        Q
# 895          27.0      0      0     315154   8.6625   NaN        S
# 896          22.0      1      1    3101298  12.2875   NaN        S
# 897          14.0      0      0       7538   9.2250   NaN        S
# 898          30.0      0      0     330972   7.6292   NaN        Q
# 899          26.0      1      1     248738  29.0000   NaN        S
# 900          18.0      0      0       2657   7.2292   NaN        C
# 901          21.0      2      0  A/4 48871  24.1500   NaN        S

# %% [markdown]
# ## Exportowanie danych

# %%
df_titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
# Zapis to csv
df_titanic.to_csv('../output/titanic_kopia.csv', index=False)

# Różnica w uwzględnianiu indeksu
df_titanic.to_csv('../output/titanic_kopia2.csv', index=True)

# Zapis do xlsx
df_tdf.to_excel('../output/tour_de_france_kopia.xlsx', index=True, sheet_name="Nazwa")

# %% [markdown]
# ## Selekcja danych

# %%
# Pobieranie jednej kolumny
slice_series = df_titanic['Name']
display(slice_series)
print(type(slice_series))

# Pobieranie jednej kolumny jako DataFrame
slice_df = df_titanic[['Name']]
display(slice_df)  
print(type(slice_df))
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                         Graham, Miss. Margaret Edith
# 889             Johnston, Miss. Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
# <class 'pandas.core.series.Series'>
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# ...                                                        ...
# 887                                      Montvila, Rev. Juozas
# 888                               Graham, Miss. Margaret Edith
# 889                   Johnston, Miss. Catherine Helen "Carrie"
# 890                                      Behr, Mr. Karl Howell
# 891                                        Dooley, Mr. Patrick
#
# [891 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# Pobranie kilku kolumn
kolumny = ['Name', 'Age']
slice_2 = df_titanic[kolumny]
display(slice_2)  
print(type(slice_2))
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# ...                                                        ...   ...
# 887                                      Montvila, Rev. Juozas  27.0
# 888                               Graham, Miss. Margaret Edith  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                                      Behr, Mr. Karl Howell  26.0
# 891                                        Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# Selekcja wierszy
display(df_titanic[:5])  # Pierwsze 5 wierszy
display(df_titanic[-5:])  # Ostatnie 5 wierszy
display(df_titanic[100:105])  # Wiersze od 100 do 104
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q
#              Survived  Pclass                              Name     Sex   Age  \
# PassengerId
# 101                 0       3           Petranec, Miss. Matilda  female  28.0
# 102                 0       3  Petroff, Mr. Pastcho ("Pentcho")    male   NaN
# 103                 0       1         White, Mr. Richard Frasar    male  21.0
# 104                 0       3        Johansson, Mr. Gustaf Joel    male  33.0
# 105                 0       3    Gustafsson, Mr. Anders Vilhelm    male  37.0
#
#              SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 101              0      0   349245   7.8958   NaN        S
# 102              0      0   349215   7.8958   NaN        S
# 103              0      1    35281  77.2875   D26        S
# 104              0      0     7540   8.6542   NaN        S
# 105              2      0  3101276   7.9250   NaN        S

# %% [markdown]
# ## Selekcja danych `.loc` i `.iloc`

# %%
# Selekcja danych .loc (wybór według etykiet)
# Istotne są etykiety!!!
#display(df_titanic.loc[0, 'Name'])  # Nie działa!!!

display(df_titanic.loc[1, 'Name'])  # Pobranie wartości z pierwszego wiersza, kolumna 'Name'
display(df_titanic.loc[1:5, ['Name', 'Age']])  # Pobranie 5 pierwszych wierszy dla kolumn 'Name' i 'Age'
display(df_titanic.loc[:, ['Name', 'Age']])  # Pobranie wszystkich wierszy dla kolumn 'Name' i 'Age'
#
display(df_titanic.loc[10:20, :])  # Wiersze od 10 do 20, wszystkie kolumny
display(df_titanic.loc[1:10:2, :])  # Między 1 a 110 wierszem co 10 wiersz
# Out:
# 'Braund, Mr. Owen Harris'
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# ...                                                        ...   ...
# 887                                      Montvila, Rev. Juozas  27.0
# 888                               Graham, Miss. Margaret Edith  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                                      Behr, Mr. Karl Howell  26.0
# 891                                        Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]
#              Survived  Pclass  \
# PassengerId
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 13                              Saundercock, Mr. William Henry    male  20.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 17                                        Rice, Master. Eugene    male   2.0
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 20                                     Masselmani, Mrs. Fatima  female   NaN
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 10               1      0     237736  30.0708   NaN        C
# 11               1      1    PP 9549  16.7000    G6        S
# 12               0      0     113783  26.5500  C103        S
# 13               0      0  A/5. 2151   8.0500   NaN        S
# 14               1      5     347082  31.2750   NaN        S
# 15               0      0     350406   7.8542   NaN        S
# 16               0      0     248706  16.0000   NaN        S
# 17               4      1     382652  29.1250   NaN        Q
# 18               0      0     244373  13.0000   NaN        S
# 19               1      0     345763  18.0000   NaN        S
# 20               0      0       2649   7.2250   NaN        C
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 3                   1       3
# 5                   0       3
# 7                   0       1
# 9                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 5                0      0            373450   8.0500   NaN        S
# 7                0      0             17463  51.8625   E46        S
# 9                0      2            347742  11.1333   NaN        S

# %%
# Selekcja danych .iloc (wybór według indeksów)
display(df_titanic.iloc[0, 2])  # Pobranie wartości z pierwszego wiersza, drugiej kolumny
display(df_titanic.iloc[:3, :2])  # Pierwsze 3 wiersze i 2 pierwsze kolumny
display(df_titanic.iloc[5:15, 1:-1])  # Wiersze od 5 do 15 wyłącznie, kolumny od 1 do przedostatniej wyłącznie
display(df_titanic.iloc[::5, :])  # Co 5. wiersz, wszystkie kolumny
# Out:
# 'Braund, Mr. Owen Harris'
#              Survived  Pclass
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#              Pclass                                               Name  \
# PassengerId
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
# 11                3                    Sandstrom, Miss. Marguerite Rut
# 12                1                           Bonnell, Miss. Elizabeth
# 13                3                     Saundercock, Mr. William Henry
# 14                3                        Andersson, Mr. Anders Johan
# 15                3               Vestrom, Miss. Hulda Amanda Adolfina
#
#                 Sex   Age  SibSp  Parch     Ticket     Fare Cabin
# PassengerId
# 6              male   NaN      0      0     330877   8.4583   NaN
# 7              male  54.0      0      0      17463  51.8625   E46
# 8              male   2.0      3      1     349909  21.0750   NaN
# 9            female  27.0      0      2     347742  11.1333   NaN
# 10           female  14.0      1      0     237736  30.0708   NaN
# 11           female   4.0      1      1    PP 9549  16.7000    G6
# 12           female  58.0      0      0     113783  26.5500  C103
# 13             male  20.0      0      0  A/5. 2151   8.0500   NaN
# 14             male  39.0      1      5     347082  31.2750   NaN
# 15           female  14.0      0      0     350406   7.8542   NaN
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 6                   0       3                              Moran, Mr. James
# 11                  1       3               Sandstrom, Miss. Marguerite Rut
# 16                  1       2              Hewlett, Mrs. (Mary D Kingcome)
# 21                  0       2                          Fynney, Mr. Joseph J
# ...               ...     ...                                           ...
# 871                 0       3                             Balkic, Mr. Cerin
# 876                 1       3              Najib, Miss. Adele Kiamie "Jane"
# 881                 1       2  Shelley, Mrs. William (Imanita Parrish Hall)
# 886                 0       3          Rice, Mrs. William (Margaret Norton)
# 891                 0       3                           Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1              male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 6              male   NaN      0      0     330877   8.4583   NaN        Q
# 11           female   4.0      1      1    PP 9549  16.7000    G6        S
# 16           female  55.0      0      0     248706  16.0000   NaN        S
# 21             male  35.0      0      0     239865  26.0000   NaN        S
# ...             ...   ...    ...    ...        ...      ...   ...      ...
# 871            male  26.0      0      0     349248   7.8958   NaN        S
# 876          female  15.0      0      0       2667   7.2250   NaN        C
# 881          female  25.0      0      1     230433  26.0000   NaN        S
# 886          female  39.0      0      5     382652  29.1250   NaN        Q
# 891            male  32.0      0      0     370376   7.7500   NaN        Q
#
# [179 rows x 11 columns]

# %% [markdown]
# ### Ćwiczenie:
# Wybierz imię i wiek dziesiątej osoby z df_titanic za pomocą loc i iloc.

# %%
print("wynik loc", df_titanic.loc[10, 'Age'])

print("wynik iloc",df_titanic.iloc[9, 4])
# Out:
# wynik loc 14.0
# wynik iloc 14.0

# %% [markdown]
# ## Łączenie DataFrame'ów

# %%
# Merge - łączenie dwóch DataFrame'ów na podstawie wspólnej kolumny
employees = pd.DataFrame({'ID': [1, 2, 3, 4], 'Name': ['Jan', 'Anna', 'Tomasz', 'Jakub']})
display(employees)

salaries = pd.DataFrame({'ID': [1, 2, 3, 5], 'Salary': [4000, 5000, 6000, 7000]})
display(salaries)

merged_df = employees.merge(salaries, left_on='ID', right_on='ID')
merged_df = employees.merge(salaries, on = 'ID', how = 'outer') # TOZSAME z wyżej
display(merged_df)
# Out:
#    ID    Name
# 0   1     Jan
# 1   2    Anna
# 2   3  Tomasz
# 3   4   Jakub
#    ID  Salary
# 0   1    4000
# 1   2    5000
# 2   3    6000
# 3   5    7000
#    ID    Name  Salary
# 0   1     Jan    4000
# 1   2    Anna    5000
# 2   3  Tomasz    6000

# %%
# Różnica między left, right, inner, outer
def merge_display(df1, df2, on, how):
    display(df1.merge(df2, on = on, how = how))

merge_display(employees, salaries, on = 'ID', how = 'left')
merge_display(employees, salaries, on = 'ID', how = 'right')
merge_display(employees, salaries, on = 'ID', how = 'inner')
merge_display(employees, salaries, on = 'ID', how = 'outer')
# Out:
#    ID    Name  Salary
# 0   1     Jan  4000.0
# 1   2    Anna  5000.0
# 2   3  Tomasz  6000.0
# 3   4   Jakub     NaN
#    ID    Name  Salary
# 0   1     Jan    4000
# 1   2    Anna    5000
# 2   3  Tomasz    6000
# 3   5     NaN    7000
#    ID    Name  Salary
# 0   1     Jan    4000
# 1   2    Anna    5000
# 2   3  Tomasz    6000
#    ID    Name  Salary
# 0   1     Jan  4000.0
# 1   2    Anna  5000.0
# 2   3  Tomasz  6000.0
# 3   4   Jakub     NaN
# 4   5     NaN  7000.0

# %%
# Join - łączenie DataFrame'ów na podstawie indeksu
left = pd.DataFrame({'A': [1, 2, 3]}, index=['a', 'b', 'd'])
display(left)
right = pd.DataFrame({'B': [4, 5, 6]}, index=['a', 'b', 'c'])
display(right)

joined_df = left.join(right, how='inner')
display(joined_df)
# Out:
#    A
# a  1
# b  2
# d  3
#    B
# a  4
# b  5
# c  6
#    A  B
# a  1  4
# b  2  5

# %%
# Concat - łączenie DataFrame'ów wierszami
#concat_df = pd.concat([left, right, left, left], axis=0)
#display(concat_df)

concat_df = pd.concat([left, right], axis=1)
display(concat_df)

concat_df = pd.concat([left, left], axis=1)
display(concat_df)

# Concat - łączenie DataFrame'ów kolumnami
df_titanic_all = pd.concat([df_titanic, df_test], axis=0)
display(df_titanic_all)
# Out:
#      A    B
# a  1.0  4.0
# b  2.0  5.0
# d  3.0  NaN
# c  NaN  6.0
#    A  A
# a  1  1
# b  2  2
# d  3  3
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 1305                                        Spector, Mr. Woolf    male   NaN
# 1306                              Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                              Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                       Ware, Mr. Frederick    male   NaN
# 1309                                  Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN        S
# 2                1      0            PC 17599   71.2833   C85        C
# 3                0      0    STON/O2. 3101282    7.9250   NaN        S
# 4                1      0              113803   53.1000  C123        S
# 5                0      0              373450    8.0500   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %% [markdown]
# ### Ćwiczenie:
# Połącz dwa DataFrame'y zawierające różne informacje o pasażerach Titanica.

# %%
df_titanic_1 = df_titanic.iloc[1:20,1:5]
df_titanic_2 = df_titanic.iloc[1:20:,6:10]

display(df_titanic_1)
display(df_titanic_2)

df_titanic_join = df_titanic_1.join(df_titanic_2)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
# 11                3                    Sandstrom, Miss. Marguerite Rut
# 12                1                           Bonnell, Miss. Elizabeth
# 13                3                     Saundercock, Mr. William Henry
# 14                3                        Andersson, Mr. Anders Johan
# 15                3               Vestrom, Miss. Hulda Amanda Adolfina
# 16                2                   Hewlett, Mrs. (Mary D Kingcome)
# 17                3                               Rice, Master. Eugene
# 18                2                       Williams, Mr. Charles Eugene
# 19                3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                3                            Masselmani, Mrs. Fatima
#
#                 Sex   Age
# PassengerId
# 2            female  38.0
# 3            female  26.0
# 4            female  35.0
# 5              male  35.0
# 6              male   NaN
# 7              male  54.0
# 8              male   2.0
# 9            female  27.0
# 10           female  14.0
# 11           female   4.0
# 12           female  58.0
# 13             male  20.0
# 14             male  39.0
# 15           female  14.0
# 16           female  55.0
# 17             male   2.0
# 18             male   NaN
# 19           female  31.0
# 20           female   NaN
#              Parch            Ticket     Fare Cabin
# PassengerId
# 2                0          PC 17599  71.2833   C85
# 3                0  STON/O2. 3101282   7.9250   NaN
# 4                0            113803  53.1000  C123
# 5                0            373450   8.0500   NaN
# 6                0            330877   8.4583   NaN
# 7                0             17463  51.8625   E46
# 8                1            349909  21.0750   NaN
# 9                2            347742  11.1333   NaN
# 10               0            237736  30.0708   NaN
# 11               1           PP 9549  16.7000    G6
# 12               0            113783  26.5500  C103
# 13               0         A/5. 2151   8.0500   NaN
# 14               5            347082  31.2750   NaN
# 15               0            350406   7.8542   NaN
# 16               0            248706  16.0000   NaN
# 17               1            382652  29.1250   NaN
# 18               0            244373  13.0000   NaN
# 19               0            345763  18.0000   NaN
# 20               0              2649   7.2250   NaN

# %%
display(df_titanic_join)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
# 11                3                    Sandstrom, Miss. Marguerite Rut
# 12                1                           Bonnell, Miss. Elizabeth
# 13                3                     Saundercock, Mr. William Henry
# 14                3                        Andersson, Mr. Anders Johan
# 15                3               Vestrom, Miss. Hulda Amanda Adolfina
# 16                2                   Hewlett, Mrs. (Mary D Kingcome)
# 17                3                               Rice, Master. Eugene
# 18                2                       Williams, Mr. Charles Eugene
# 19                3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                3                            Masselmani, Mrs. Fatima
#
#                 Sex   Age  Parch            Ticket     Fare Cabin
# PassengerId
# 2            female  38.0      0          PC 17599  71.2833   C85
# 3            female  26.0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      0            113803  53.1000  C123
# 5              male  35.0      0            373450   8.0500   NaN
# 6              male   NaN      0            330877   8.4583   NaN
# 7              male  54.0      0             17463  51.8625   E46
# 8              male   2.0      1            349909  21.0750   NaN
# 9            female  27.0      2            347742  11.1333   NaN
# 10           female  14.0      0            237736  30.0708   NaN
# 11           female   4.0      1           PP 9549  16.7000    G6
# 12           female  58.0      0            113783  26.5500  C103
# 13             male  20.0      0         A/5. 2151   8.0500   NaN
# 14             male  39.0      5            347082  31.2750   NaN
# 15           female  14.0      0            350406   7.8542   NaN
# 16           female  55.0      0            248706  16.0000   NaN
# 17             male   2.0      1            382652  29.1250   NaN
# 18             male   NaN      0            244373  13.0000   NaN
# 19           female  31.0      0            345763  18.0000   NaN
# 20           female   NaN      0              2649   7.2250   NaN

# %%
df_titanic_merge = pd.merge(df_titanic_1, df_titanic_2, left_index = True, right_index = True)
display(df_titanic_merge)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
# 11                3                    Sandstrom, Miss. Marguerite Rut
# 12                1                           Bonnell, Miss. Elizabeth
# 13                3                     Saundercock, Mr. William Henry
# 14                3                        Andersson, Mr. Anders Johan
# 15                3               Vestrom, Miss. Hulda Amanda Adolfina
# 16                2                   Hewlett, Mrs. (Mary D Kingcome)
# 17                3                               Rice, Master. Eugene
# 18                2                       Williams, Mr. Charles Eugene
# 19                3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                3                            Masselmani, Mrs. Fatima
#
#                 Sex   Age  Parch            Ticket     Fare Cabin
# PassengerId
# 2            female  38.0      0          PC 17599  71.2833   C85
# 3            female  26.0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      0            113803  53.1000  C123
# 5              male  35.0      0            373450   8.0500   NaN
# 6              male   NaN      0            330877   8.4583   NaN
# 7              male  54.0      0             17463  51.8625   E46
# 8              male   2.0      1            349909  21.0750   NaN
# 9            female  27.0      2            347742  11.1333   NaN
# 10           female  14.0      0            237736  30.0708   NaN
# 11           female   4.0      1           PP 9549  16.7000    G6
# 12           female  58.0      0            113783  26.5500  C103
# 13             male  20.0      0         A/5. 2151   8.0500   NaN
# 14             male  39.0      5            347082  31.2750   NaN
# 15           female  14.0      0            350406   7.8542   NaN
# 16           female  55.0      0            248706  16.0000   NaN
# 17             male   2.0      1            382652  29.1250   NaN
# 18             male   NaN      0            244373  13.0000   NaN
# 19           female  31.0      0            345763  18.0000   NaN
# 20           female   NaN      0              2649   7.2250   NaN
